# %%
1. Напишите крон, который будет запускаться каждую пятницу в 9 часов вечера.
    Ответ:  * 21 * * 5

2. Напишите крон, который будет запускаться каждое воскресенье марта месяца на протяжении всего дня с интервалом в 4 часа (т.е. запуск будет в 2021-03-07 00:00:00, затем 2021-03-07 04:00:00 и т.д.)
    Ответ:  * */4 * 3 7
        
3. Отметьте все картинки, где изображен направленный ациклический граф.
    Ответ: 1 вариант ответа - карт.№1,  2 вариант ответа - нет правильной картинки.
        
4. Опишите своими словами, как Вы поняли, чем отличается task от operator?
    Ответ: Операторы это узлы, звенья в цепочке DAG графа. Опреаторы описывают, какую задачу необходимо выполнить. 
           Задача это функция или скрипт, которые запускаются, исполняются, так, как описано в операторе.
